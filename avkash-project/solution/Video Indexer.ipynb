# %%
# !pip install video_indexer
# Out:
# Collecting video_indexer
#   Downloading video_indexer-0.1.8-py3-none-any.whl (4.5 kB)
# Requirement already satisfied: requests in /Users/avkashchauhan99/opt/anaconda3/lib/python3.8/site-packages (from video_indexer) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/avkashchauhan99/opt/anaconda3/lib/python3.8/site-packages (from requests->video_indexer) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/avkashchauhan99/opt/anaconda3/lib/python3.8/site-packages (from requests->video_indexer) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/avkashchauhan99/opt/anaconda3/lib/python3.8/site-packages (from requests->video_indexer) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/avkashchauhan99/opt/anaconda3/lib/python3.8/site-packages (from requests->video_indexer) (3.0.4)
# Installing collected packages: video-indexer
# Successfully installed video-indexer-0.1.8

# %% [markdown]
# ### Documentation
# - https://docs.microsoft.com/en-us/azure/azure-video-analyzer/video-analyzer-for-media-docs/video-indexer-use-apis
#
# ### To get
# - https://www.videoindexer.ai/account
#
# ### To Get API Subscription:
# https://api-portal.videoindexer.ai/
#
# ### Article
# - https://medium.com/microsoftazure/visual-brand-detection-with-azure-video-indexer-cd65330b908c

# %%
from video_indexer import VideoIndexer

CONFIG = {
    'SUBSCRIPTION_KEY': 'bcbaaa4254574c2997ee22b69946b42e',
    'LOCATION': 'trial',
    'ACCOUNT_ID': 'd1629197-588b-40a7-98fa-e19785ca082e'
}

vi = VideoIndexer(
    vi_subscription_key=CONFIG['SUBSCRIPTION_KEY'],
    vi_location=CONFIG['LOCATION'],
    vi_account_id=CONFIG['ACCOUNT_ID']
)

# %%
vi.check_access_token()
# Out:
# Getting video indexer access token...
# Access Token: eyJhbGciOiJodHRwOi8vd3d3LnczLm9yZy8yMDAxLzA0L3htbGRzaWctbW9yZSNobWFjLXNoYTI1NiIsInR5cCI6IkpXVCJ9..jYKwiU0bbKScnNYYGvIatRjcfkQR8PTxlM0UoEF8q9M

# %%
vi.get_video_info('fbb0f35f04')
# Out:
# Getting video info for: fbb0f35f04
# {'partition': None,
#  'description': None,
#  'privacyMode': 'Private',
#  'state': 'Processed',
#  'accountId': 'd1629197-588b-40a7-98fa-e19785ca082e',
#  'id': 'fbb0f35f04',
#  'name': 'kiosk-02',
#  'userName': 'Avkash Chauhan',
#  'created': '2021-06-27T15:46:11.5110739+00:00',
#  'isOwned': True,
#  'isEditable': True,
#  'isBase': True,
#  'durationInSeconds': 19,
#  'summarizedInsights': {'name': 'kiosk-02',
#   'id': 'fbb0f35f04',
#   'privacyMode': 'Private',
#   'duration': {'time': '0:00:19.968', 'seconds': 20},
#   'thumbnailVideoId': 'fbb0f35f04',
#   'thumbnailId': '89bc527b-78d9-4f55-88a0-aea45ae4019c',
#   'faces': [{'videoId': 'fbb0f35f04',
#     'confidence': 0,
#     'description': None,
#     'title': None,
#     'thumbnailId': 'a070a8be-5cdd-4e33-87ab-acf47ca7df8b',
#     'seenDuration': 19.8,
#     'seenDurationRatio': 0.9916,
#     'id': 1000,
#     'name': 'Unknown #1',
#     'appearances': [{'startTime': '0:00:00.067',
#       'endTime': '0:00:19.853',
#       'startSeconds': 0.1,
#       'endSeconds': 19.9}]}],
#   'keywords': [],
#   'sentiments': [{'sentimentKey': 'Neutral',
#     'seenDurationRatio': 0.9515,
#     'appearances': [{'startTime': '0:00:00',
#       'endTime': '0:00:18.95',
#       'startSeconds': 0,
#       'endSeconds': 19}]},
#    {'sentimentKey': 'Positive',
#     'seenDurationRatio': 0.0451,
#     'appearances': [{'startTime': '0:00:18.95',
#       'endTime': '0:00:19.921',
#       'startSeconds': 19,
#       'endSeconds': 19.9}]}],
#   'emotions': [],
#   'audioEffects': [{'audioEffectKey': 'Silence',
#     'seenDurationRatio': 0.1202,
#     'seenDuration': 2.4,
#     'appearances': [{'confidence': 1,
#       'startTime': '0:00:14.45',
#       'endTime': '0:00:16.85',
#       'startSeconds': 14.4,
#       'endSeconds': 16.8}]}],
#   'labels': [{'id': 1,
#     'name': 'person',
#     'appearances': [{'confidence': 0.9891,
#       'startTime': '0:00:00',
#       'endTime': '0:00:19.85',
#       'startSeconds': 0,
#       'endSeconds': 19.8}]},
#    {'id': 2,
#     'name': 'human face',
#     'appearances': [{'confidence': 0.989,
#       'startTime': '0:00:00',
#       'endTime': '0:00:19.85',
#       'startSeconds': 0,
#       'endSeconds': 19.8}]},
#    {'id': 3,
#     'name': 'wall',
#     'appearances': [{'confidence': 0.9715,
#       'startTime': '0:00:00',
#       'endTime': '0:00:19.85',
#       'startSeconds': 0,
#       'endSeconds': 19.8}]},
#    {'id': 4,
#     'name': 'man',
#     'appearances': [{'confidence': 0.9018,
#       'startTime': '0:00:00',
#       'endTime': '0:00:19.85',
#       'startSeconds': 0,
#       'endSeconds': 19.8}]},
#    {'id': 5,
#     'name': 'glasses',
#     'appearances': [{'confidence': 0.9516,
#       'startTime': '0:00:00',
#       'endTime': '0:00:19.85',
#       'startSeconds': 0,
#       'endSeconds': 19.8}]},
#    {'id': 7,
#     'name': 'indoor',
#     'appearances': [{'confidence': 0.8701,
#       'startTime': '0:00:00',
#       'endTime': '0:00:19.85',
#       'startSeconds': 0,
#       'endSeconds': 19.8}]},
#    {'id': 8,
#     'name': 'clothing',
#     'appearances': [{'confidence': 0.9492,
#       'startTime': '0:00:00',
#       'endTime': '0:00:19.85',
#       'startSeconds': 0,
#       'endSeconds': 19.8}]},
#    {'id': 9,
#     'name': 'cap',
#     'appearances': [{'confidence': 0.9194,
#       'startTime': '0:00:00',
#       'endTime': '0:00:19.85',
#       'startSeconds': 0,
#       'endSeconds': 19.8}]},
#    {'id': 10,
#     'name': 'wearing',
#     'appearances': [{'confidence': 0.9573,
#       'startTime': '0:00:00',
#       'endTime': '0:00:19.85',
#       'startSeconds': 0,
#       'endSeconds': 19.8}]},
#    {'id': 11,
#     'name': 'fashion accessory',
#     'appearances': [{'confidence': 0.941,
#       'startTime': '0:00:00',
#       'endTime': '0:00:19.85',
#       'startSeconds': 0,
#       'endSeconds': 19.8}]},
#    {'id': 13,
#     'name': 'hat',
#     'appearances': [{'confidence': 0.9603,
#       'startTime': '0:00:00',
#       'endTime': '0:00:19.85',
#       'startSeconds': 0,
#       'endSeconds': 19.8}]},
#    {'id': 14,
#     'name': 'cool',
#     'appearances': [{'confidence': 0.91,
#       'startTime': '0:00:01.068',
#       'endTime': '0:00:19.217',
#       'startSeconds': 1.1,
#       'endSeconds': 19.2}]},
#    {'id': 17,
#     'name': 'selfie',
#     'appearances': [{'confidence': 0.9228,
#       'startTime': '0:00:02.135',
#       'endTime': '0:00:19.85',
#       'startSeconds': 2.1,
#       'endSeconds': 19.8}]},
#    {'id': 12,
#     'name': 'baseball cap',
#     'appearances': [{'confidence': 0.9218,
#       'startTime': '0:00:00',
#       'endTime': '0:00:07.473',
#       'startSeconds': 0,
#       'endSeconds': 7.5},
#      {'confidence': 0.9153,
#       'startTime': '0:00:14.946',
#       'endTime': '0:00:19.85',
#       'startSeconds': 14.9,
#       'endSeconds': 19.8}]},
#    {'id': 19,
#     'name': 'shirt',
#     'appearances': [{'confidence': 0.9551,
#       'startTime': '0:00:07.473',
#       'endTime': '0:00:14.946',
#       'startSeconds': 7.5,
#       'endSeconds': 14.9}]},
#    {'id': 18,
#     'name': 'helmet',
#     'appearances': [{'confidence': 0.8286,
#       'startTime': '0:00:03.203',
#       'endTime': '0:00:04.271',
#       'startSeconds': 3.2,
#       'endSeconds': 4.3},
#      {'confidence': 0.8049,
#       'startTime': '0:00:09.608',
#       'endTime': '0:00:10.676',
#       'startSeconds': 9.6,
#       'endSeconds': 10.7},
#      {'confidence': 0.901,
#       'startTime': '0:00:18.149',
#       'endTime': '0:00:19.217',
#       'startSeconds': 18.1,
#       'endSeconds': 19.2}]},
#    {'id': 6,
#     'name': 'human beard',
#     'appearances': [{'confidence': 0.932,
#       'startTime': '0:00:00',
#       'endTime': '0:00:01.068',
#       'startSeconds': 0,
#       'endSeconds': 1.1},
#      {'confidence': 0.9275,
#       'startTime': '0:00:06.405',
#       'endTime': '0:00:07.473',
#       'startSeconds': 6.4,
#       'endSeconds': 7.5},
#      {'confidence': 0.9036,
#       'startTime': '0:00:17.081',
#       'endTime': '0:00:18.149',
#       'startSeconds': 17.1,
#       'endSeconds': 18.1}]},
#    {'id': 16,
#     'name': 'smile',
#     'appearances': [{'confidence': 0.9482,
#       'startTime': '0:00:02.135',
#       'endTime': '0:00:03.203',
#       'startSeconds': 2.1,
#       'endSeconds': 3.2},
#      {'confidence': 0.9213,
#       'startTime': '0:00:07.473',
#       'endTime': '0:00:08.541',
#       'startSeconds': 7.5,
#       'endSeconds': 8.5},
#      {'confidence': 0.951,
#       'startTime': '0:00:19.216',
#       'endTime': '0:00:19.85',
#       'startSeconds': 19.2,
#       'endSeconds': 19.8}]},
#    {'id': 15,
#     'name': 'goggles',
#     'appearances': [{'confidence': 0.902,
#       'startTime': '0:00:01.068',
#       'endTime': '0:00:02.136',
#       'startSeconds': 1.1,
#       'endSeconds': 2.1}]},
#    {'id': 20,
#     'name': 'smiling',
#     'appearances': [{'confidence': 0.919,
#       'startTime': '0:00:19.216',
#       'endTime': '0:00:19.85',
#       'startSeconds': 19.2,
#       'endSeconds': 19.8}]}],
#   'framePatterns': [],
#   'brands': [],
#   'namedLocations': [{'referenceId': None,
#     'referenceUrl': None,
#     'confidence': 0.52,
#     'description': None,
#     'seenDuration': 5.7,
#     'id': 1,
#     'name': 'Circuit',
#     'appearances': [{'startTime': '0:00:08.66',
#       'endTime': '0:00:14.45',
#       'startSeconds': 8.7,
#       'endSeconds': 14.4}]}],
#   'namedPeople': [],
#   'statistics': {'correspondenceCount': 0,
#    'speakerTalkToListenRatio': {'1': 1},
#    'speakerLongestMonolog': {'1': 17},
#    'speakerNumberOfFragments': {'1': 2},
#    'speakerWordCount': {'1': 14}},
#   'topics': []},
#  'videos': [{'accountId': 'd1629197-588b-40a7-98fa-e19785ca082e',
#    'id': 'fbb0f35f04',
#    'state': 'Processed',
#    'moderationState': 'OK',
#    'reviewState': 'None',
#    'privacyMode': 'Private',
#    'processingProgress': '100%',
#    'failureCode': 'None',
#    'failureMessage': '',
#    'externalId': None,
#    'externalUrl': None,
#    'metadata': None,
#    'insights': {'version': '1.0.0.0',
#     'duration': '0:00:19.968',
#     'sourceLanguage': 'en-US',
#     'sourceLanguages': ['en-US'],
#     'language': 'en-US',
#     'languages': ['en-US'],
#     'transcript': [{'id': 1,
#       'text': 'So find this. Before my ID.',
#       'confidence': 0.8284,
#       'speakerId': 1,
#       'language': 'en-US',
#       'instances': [{'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:08.66',
#         'start': '0:00:00',
#         'end': '0:00:08.66'}]},
#      {'id': 2,
#       'text': 'My boarding pass. Circuit. Checked.',
#       'confidence': 0.9865,
#       'speakerId': 1,
#       'language': 'en-US',
#       'instances': [{'adjustedStart': '0:00:08.66',
#         'adjustedEnd': '0:00:14.45',
#         'start': '0:00:08.66',
#         'end': '0:00:14.45'}]},
#      {'id': 3,
#       'text': 'Job done. Perfect.',
#       'confidence': 0.949,
#       'speakerId': 1,
#       'language': 'en-US',
#       'instances': [{'adjustedStart': '0:00:16.81',
#         'adjustedEnd': '0:00:19.921',
#         'start': '0:00:16.81',
#         'end': '0:00:19.921'}]}],
#     'ocr': [{'id': 1,
#       'text': 'box',
#       'confidence': 0.382,
#       'left': 446,
#       'top': 534,
#       'width': 182,
#       'height': 98,
#       'language': 'en-US',
#       'instances': [{'adjustedStart': '0:00:02.803',
#         'adjustedEnd': '0:00:06.803',
#         'start': '0:00:02.803',
#         'end': '0:00:06.803'},
#        {'adjustedStart': '0:00:13.547',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:13.547',
#         'end': '0:00:19.85'}]}],
#     'faces': [{'id': 1000,
#       'name': 'Unknown #1',
#       'confidence': 0,
#       'description': None,
#       'thumbnailId': 'a070a8be-5cdd-4e33-87ab-acf47ca7df8b',
#       'title': None,
#       'imageUrl': None,
#       'thumbnails': [{'id': '508dda6c-ca43-4198-af20-d1016df0cc76',
#         'fileName': 'FaceInstanceThumbnail_508dda6c-ca43-4198-af20-d1016df0cc76.jpg',
#         'instances': [{'adjustedStart': '0:00:00.067',
#           'adjustedEnd': '0:00:00.1',
#           'start': '0:00:00.067',
#           'end': '0:00:00.1'}]},
#        {'id': 'a070a8be-5cdd-4e33-87ab-acf47ca7df8b',
#         'fileName': 'FaceInstanceThumbnail_a070a8be-5cdd-4e33-87ab-acf47ca7df8b.jpg',
#         'instances': [{'adjustedStart': '0:00:01.735',
#           'adjustedEnd': '0:00:01.768',
#           'start': '0:00:01.735',
#           'end': '0:00:01.768'}]},
#        {'id': '5a9d339a-65b3-4159-ab82-1254b4d4c82c',
#         'fileName': 'FaceInstanceThumbnail_5a9d339a-65b3-4159-ab82-1254b4d4c82c.jpg',
#         'instances': [{'adjustedStart': '0:00:05.071',
#           'adjustedEnd': '0:00:05.104',
#           'start': '0:00:05.071',
#           'end': '0:00:05.104'}]},
#        {'id': 'd6435358-341c-4a0a-85ee-cb2808c69abe',
#         'fileName': 'FaceInstanceThumbnail_d6435358-341c-4a0a-85ee-cb2808c69abe.jpg',
#         'instances': [{'adjustedStart': '0:00:10.075',
#           'adjustedEnd': '0:00:10.108',
#           'start': '0:00:10.075',
#           'end': '0:00:10.108'}]},
#        {'id': '71b42b13-761f-4ad1-95f2-ce5c0404cea0',
#         'fileName': 'FaceInstanceThumbnail_71b42b13-761f-4ad1-95f2-ce5c0404cea0.jpg',
#         'instances': [{'adjustedStart': '0:00:15.079',
#           'adjustedEnd': '0:00:15.112',
#           'start': '0:00:15.079',
#           'end': '0:00:15.112'}]}],
#       'instances': [{'thumbnailsIds': ['5a9d339a-65b3-4159-ab82-1254b4d4c82c',
#          '508dda6c-ca43-4198-af20-d1016df0cc76',
#          'd6435358-341c-4a0a-85ee-cb2808c69abe',
#          '71b42b13-761f-4ad1-95f2-ce5c0404cea0',
#          'a070a8be-5cdd-4e33-87ab-acf47ca7df8b'],
#         'adjustedStart': '0:00:00.067',
#         'adjustedEnd': '0:00:19.853',
#         'start': '0:00:00.067',
#         'end': '0:00:19.853'}]}],
#     'labels': [{'id': 1,
#       'name': 'person',
#       'referenceId': 'person',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9891,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:00',
#         'end': '0:00:19.85'}]},
#      {'id': 2,
#       'name': 'human face',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.989,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:00',
#         'end': '0:00:19.85'}]},
#      {'id': 3,
#       'name': 'wall',
#       'referenceId': 'structure/wall',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9715,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:00',
#         'end': '0:00:19.85'}]},
#      {'id': 4,
#       'name': 'man',
#       'referenceId': 'person/man',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9191,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:02.136',
#         'start': '0:00:00',
#         'end': '0:00:02.136'},
#        {'confidence': 0.9018,
#         'adjustedStart': '0:00:03.203',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:03.203',
#         'end': '0:00:19.85'}]},
#      {'id': 5,
#       'name': 'glasses',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9516,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:00',
#         'end': '0:00:19.85'}]},
#      {'id': 6,
#       'name': 'human beard',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.932,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:01.068',
#         'start': '0:00:00',
#         'end': '0:00:01.068'},
#        {'confidence': 0.9275,
#         'adjustedStart': '0:00:06.405',
#         'adjustedEnd': '0:00:07.473',
#         'start': '0:00:06.405',
#         'end': '0:00:07.473'},
#        {'confidence': 0.9036,
#         'adjustedStart': '0:00:17.081',
#         'adjustedEnd': '0:00:18.149',
#         'start': '0:00:17.081',
#         'end': '0:00:18.149'}]},
#      {'id': 7,
#       'name': 'indoor',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.8701,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:00',
#         'end': '0:00:19.85'}]},
#      {'id': 8,
#       'name': 'clothing',
#       'referenceId': 'consumer goods/clothing',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9492,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:00',
#         'end': '0:00:19.85'}]},
#      {'id': 9,
#       'name': 'cap',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9219,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:10.676',
#         'start': '0:00:00',
#         'end': '0:00:10.676'},
#        {'confidence': 0.9194,
#         'adjustedStart': '0:00:11.743',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:11.743',
#         'end': '0:00:19.85'}]},
#      {'id': 10,
#       'name': 'wearing',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9573,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:00',
#         'end': '0:00:19.85'}]},
#      {'id': 11,
#       'name': 'fashion accessory',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.948,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:10.676',
#         'start': '0:00:00',
#         'end': '0:00:10.676'},
#        {'confidence': 0.941,
#         'adjustedStart': '0:00:11.743',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:11.743',
#         'end': '0:00:19.85'}]},
#      {'id': 12,
#       'name': 'baseball cap',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9128,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:02.136',
#         'start': '0:00:00',
#         'end': '0:00:02.136'},
#        {'confidence': 0.9218,
#         'adjustedStart': '0:00:04.27',
#         'adjustedEnd': '0:00:07.473',
#         'start': '0:00:04.27',
#         'end': '0:00:07.473'},
#        {'confidence': 0.9086,
#         'adjustedStart': '0:00:14.946',
#         'adjustedEnd': '0:00:16.014',
#         'start': '0:00:14.946',
#         'end': '0:00:16.014'},
#        {'confidence': 0.9153,
#         'adjustedStart': '0:00:17.081',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:17.081',
#         'end': '0:00:19.85'}]},
#      {'id': 13,
#       'name': 'hat',
#       'referenceId': 'clothing/headdress/hat',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9603,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:00',
#         'end': '0:00:19.85'}]},
#      {'id': 14,
#       'name': 'cool',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9155,
#         'adjustedStart': '0:00:01.068',
#         'adjustedEnd': '0:00:03.203',
#         'start': '0:00:01.068',
#         'end': '0:00:03.203'},
#        {'confidence': 0.9104,
#         'adjustedStart': '0:00:05.338',
#         'adjustedEnd': '0:00:08.541',
#         'start': '0:00:05.338',
#         'end': '0:00:08.541'},
#        {'confidence': 0.91,
#         'adjustedStart': '0:00:10.676',
#         'adjustedEnd': '0:00:19.217',
#         'start': '0:00:10.676',
#         'end': '0:00:19.217'}]},
#      {'id': 15,
#       'name': 'goggles',
#       'referenceId': 'device/optical instrument/goggles',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.902,
#         'adjustedStart': '0:00:01.068',
#         'adjustedEnd': '0:00:02.136',
#         'start': '0:00:01.068',
#         'end': '0:00:02.136'}]},
#      {'id': 16,
#       'name': 'smile',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9482,
#         'adjustedStart': '0:00:02.135',
#         'adjustedEnd': '0:00:03.203',
#         'start': '0:00:02.135',
#         'end': '0:00:03.203'},
#        {'confidence': 0.9213,
#         'adjustedStart': '0:00:07.473',
#         'adjustedEnd': '0:00:08.541',
#         'start': '0:00:07.473',
#         'end': '0:00:08.541'},
#        {'confidence': 0.951,
#         'adjustedStart': '0:00:19.216',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:19.216',
#         'end': '0:00:19.85'}]},
#      {'id': 17,
#       'name': 'selfie',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9219,
#         'adjustedStart': '0:00:02.135',
#         'adjustedEnd': '0:00:09.609',
#         'start': '0:00:02.135',
#         'end': '0:00:09.609'},
#        {'confidence': 0.9211,
#         'adjustedStart': '0:00:10.676',
#         'adjustedEnd': '0:00:16.014',
#         'start': '0:00:10.676',
#         'end': '0:00:16.014'},
#        {'confidence': 0.9228,
#         'adjustedStart': '0:00:17.081',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:17.081',
#         'end': '0:00:19.85'}]},
#      {'id': 18,
#       'name': 'helmet',
#       'referenceId': 'covering/protective covering/helmet',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.8286,
#         'adjustedStart': '0:00:03.203',
#         'adjustedEnd': '0:00:04.271',
#         'start': '0:00:03.203',
#         'end': '0:00:04.271'},
#        {'confidence': 0.8049,
#         'adjustedStart': '0:00:09.608',
#         'adjustedEnd': '0:00:10.676',
#         'start': '0:00:09.608',
#         'end': '0:00:10.676'},
#        {'confidence': 0.901,
#         'adjustedStart': '0:00:18.149',
#         'adjustedEnd': '0:00:19.217',
#         'start': '0:00:18.149',
#         'end': '0:00:19.217'}]},
#      {'id': 19,
#       'name': 'shirt',
#       'referenceId': 'consumer goods/clothing/shirt',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9519,
#         'adjustedStart': '0:00:07.473',
#         'adjustedEnd': '0:00:08.541',
#         'start': '0:00:07.473',
#         'end': '0:00:08.541'},
#        {'confidence': 0.9574,
#         'adjustedStart': '0:00:09.608',
#         'adjustedEnd': '0:00:10.676',
#         'start': '0:00:09.608',
#         'end': '0:00:10.676'},
#        {'confidence': 0.9615,
#         'adjustedStart': '0:00:11.743',
#         'adjustedEnd': '0:00:12.811',
#         'start': '0:00:11.743',
#         'end': '0:00:12.811'},
#        {'confidence': 0.9551,
#         'adjustedStart': '0:00:13.878',
#         'adjustedEnd': '0:00:14.946',
#         'start': '0:00:13.878',
#         'end': '0:00:14.946'}]},
#      {'id': 20,
#       'name': 'smiling',
#       'referenceId': 'gesture/smile/smiling',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.919,
#         'adjustedStart': '0:00:19.216',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:19.216',
#         'end': '0:00:19.85'}]}],
#     'scenes': [{'id': 1,
#       'instances': [{'adjustedStart': '0:00:00.2',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:00.2',
#         'end': '0:00:19.85'}]}],
#     'shots': [{'id': 1,
#       'tags': ['CloseUp', 'CenterFace', 'Indoor'],
#       'keyFrames': [{'id': 1,
#         'instances': [{'thumbnailId': 'd3c8883a-88a3-43a7-9e9f-fbd774311933',
#           'adjustedStart': '0:00:00.2',
#           'adjustedEnd': '0:00:00.233',
#           'start': '0:00:00.2',
#           'end': '0:00:00.233'}]},
#        {'id': 2,
#         'instances': [{'thumbnailId': 'a51617ae-35ac-49e7-909c-b1953f537e6a',
#           'adjustedStart': '0:00:09.908',
#           'adjustedEnd': '0:00:09.941',
#           'start': '0:00:09.908',
#           'end': '0:00:09.941'}]}],
#       'instances': [{'adjustedStart': '0:00:00.2',
#         'adjustedEnd': '0:00:19.85',
#         'start': '0:00:00.2',
#         'end': '0:00:19.85'}]}],
#     'namedLocations': [{'id': 1,
#       'name': 'Circuit',
#       'referenceId': None,
#       'referenceUrl': None,
#       'description': None,
#       'tags': [],
#       'confidence': 0.52,
#       'isCustom': False,
#       'instances': [{'instanceSource': 'Transcript',
#         'adjustedStart': '0:00:08.66',
#         'adjustedEnd': '0:00:14.45',
#         'start': '0:00:08.66',
#         'end': '0:00:14.45'}]}],
#     'audioEffects': [{'id': 0,
#       'type': 'Silence',
#       'name': 'Silence',
#       'instances': [{'confidence': 1,
#         'adjustedStart': '0:00:14.45',
#         'adjustedEnd': '0:00:16.85',
#         'start': '0:00:14.45',
#         'end': '0:00:16.85'}]}],
#     'sentiments': [{'id': 1,
#       'averageScore': 0.594,
#       'sentimentType': 'Neutral',
#       'instances': [{'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:02.85',
#         'start': '0:00:00',
#         'end': '0:00:02.85'},
#        {'adjustedStart': '0:00:05.25',
#         'adjustedEnd': '0:00:14.45',
#         'start': '0:00:05.25',
#         'end': '0:00:14.45'},
#        {'adjustedStart': '0:00:16.81',
#         'adjustedEnd': '0:00:18.95',
#         'start': '0:00:16.81',
#         'end': '0:00:18.95'}]},
#      {'id': 2,
#       'averageScore': 0.9682,
#       'sentimentType': 'Positive',
#       'instances': [{'adjustedStart': '0:00:18.95',
#         'adjustedEnd': '0:00:19.921',
#         'start': '0:00:18.95',
#         'end': '0:00:19.921'}]}],
#     'blocks': [{'id': 0,
#       'instances': [{'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:19.921',
#         'start': '0:00:00',
#         'end': '0:00:19.921'}]}],
#     'speakers': [{'id': 1,
#       'name': 'Speaker #1',
#       'instances': [{'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:14.45',
#         'start': '0:00:00',
#         'end': '0:00:14.45'},
#        {'adjustedStart': '0:00:16.81',
#         'adjustedEnd': '0:00:19.921',
#         'start': '0:00:16.81',
#         'end': '0:00:19.921'}]}],
#     'textualContentModeration': {'id': 0,
#      'bannedWordsCount': 0,
#      'bannedWordsRatio': 0,
#      'instances': []},
#     'statistics': {'correspondenceCount': 0,
#      'speakerTalkToListenRatio': {'1': 1},
#      'speakerLongestMonolog': {'1': 17},
#      'speakerNumberOfFragments': {'1': 2},
#      'speakerWordCount': {'1': 14}}},
#    'thumbnailId': '89bc527b-78d9-4f55-88a0-aea45ae4019c',
#    'detectSourceLanguage': False,
#    'languageAutoDetectMode': 'None',
#    'sourceLanguage': 'en-US',
#    'sourceLanguages': ['en-US'],
#    'language': 'en-US',
#    'languages': ['en-US'],
#    'indexingPreset': 'Default',
#    'linguisticModelId': '00000000-0000-0000-0000-000000000000',
#    'personModelId': '00000000-0000-0000-0000-000000000000',
#    'isAdult': False,
#    'publishedUrl': 'https://rodmandev.streaming.mediaservices.windows.net/49f52785-4ee0-4553-ae72-85ee73b90257/kiosk-02.ism/manifest(encryption=cbc)',
#    'publishedProxyUrl': None,
#    'viewToken': 'Bearer=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1cm46bWljcm9zb2Z0OmF6dXJlOm1lZGlhc2VydmljZXM6Y29udGVudGtleWlkZW50aWZpZXIiOiI2OGMyNzc3Ny1jZDkzLTRjYzQtOWI1Yi1jMTA0MzNhODA2ZmYiLCJuYmYiOjE2MjQ4MTE1MTYsImV4cCI6MTYyNDg1NDc3NiwiaXNzIjoiaHR0cHM6Ly9icmVha2Rvd24ubWUiLCJhdWQiOiJCcmVha2Rvd25Vc2VyIn0.-4n9cuwt56eMV4DLZGXGa8dmxMEm1lDGOFcjvIwJ4WE'}],
#  'videosRanges': [{'videoId': 'fbb0f35f04',
#    'range': {'start': '0:00:00', 'end': '0:00:19.968'}}]}

# %%
video_id = 'fbb0f35f04'

# %%
info = vi.get_video_info(video_id, video_language='English')
# Out:
# Getting video info for: fbb0f35f04

# %%
info['videos'][0]['insights']['faces'][0]
# Out:
# {'id': 1000,
#  'name': 'Unknown #1',
#  'confidence': 0,
#  'description': None,
#  'thumbnailId': 'a070a8be-5cdd-4e33-87ab-acf47ca7df8b',
#  'title': None,
#  'imageUrl': None,
#  'thumbnails': [{'id': '508dda6c-ca43-4198-af20-d1016df0cc76',
#    'fileName': 'FaceInstanceThumbnail_508dda6c-ca43-4198-af20-d1016df0cc76.jpg',
#    'instances': [{'adjustedStart': '0:00:00.067',
#      'adjustedEnd': '0:00:00.1',
#      'start': '0:00:00.067',
#      'end': '0:00:00.1'}]},
#   {'id': 'a070a8be-5cdd-4e33-87ab-acf47ca7df8b',
#    'fileName': 'FaceInstanceThumbnail_a070a8be-5cdd-4e33-87ab-acf47ca7df8b.jpg',
#    'instances': [{'adjustedStart': '0:00:01.735',
#      'adjustedEnd': '0:00:01.768',
#      'start': '0:00:01.735',
#      'end': '0:00:01.768'}]},
#   {'id': '5a9d339a-65b3-4159-ab82-1254b4d4c82c',
#    'fileName': 'FaceInstanceThumbnail_5a9d339a-65b3-4159-ab82-1254b4d4c82c.jpg',
#    'instances': [{'adjustedStart': '0:00:05.071',
#      'adjustedEnd': '0:00:05.104',
#      'start': '0:00:05.071',
#      'end': '0:00:05.104'}]},
#   {'id': 'd6435358-341c-4a0a-85ee-cb2808c69abe',
#    'fileName': 'FaceInstanceThumbnail_d6435358-341c-4a0a-85ee-cb2808c69abe.jpg',
#    'instances': [{'adjustedStart': '0:00:10.075',
#      'adjustedEnd': '0:00:10.108',
#      'start': '0:00:10.075',
#      'end': '0:00:10.108'}]},
#   {'id': '71b42b13-761f-4ad1-95f2-ce5c0404cea0',
#    'fileName': 'FaceInstanceThumbnail_71b42b13-761f-4ad1-95f2-ce5c0404cea0.jpg',
#    'instances': [{'adjustedStart': '0:00:15.079',
#      'adjustedEnd': '0:00:15.112',
#      'start': '0:00:15.079',
#      'end': '0:00:15.112'}]}],
#  'instances': [{'thumbnailsIds': ['5a9d339a-65b3-4159-ab82-1254b4d4c82c',
#     '508dda6c-ca43-4198-af20-d1016df0cc76',
#     'd6435358-341c-4a0a-85ee-cb2808c69abe',
#     '71b42b13-761f-4ad1-95f2-ce5c0404cea0',
#     'a070a8be-5cdd-4e33-87ab-acf47ca7df8b'],
#    'adjustedStart': '0:00:00.067',
#    'adjustedEnd': '0:00:19.853',
#    'start': '0:00:00.067',
#    'end': '0:00:19.853'}]}

# %%
img_code = vi.get_thumbnail_from_video_indexer(video_id,  '71b42b13-761f-4ad1-95f2-ce5c0404cea0')
img_stream = io.BytesIO(img_str)
# Out:
# Getting thumbnail from video: fbb0f35f04, thumbnail: 71b42b13-761f-4ad1-95f2-ce5c0404cea0

# %%
img = Image.open(img_stream)
imshow(img)

# %%
info['summarizedInsights']['faces']
# Out:
# [{'videoId': 'fbb0f35f04',
#   'confidence': 0,
#   'description': None,
#   'title': None,
#   'thumbnailId': 'a070a8be-5cdd-4e33-87ab-acf47ca7df8b',
#   'seenDuration': 19.8,
#   'seenDurationRatio': 0.9916,
#   'id': 1000,
#   'name': 'Unknown #1',
#   'appearances': [{'startTime': '0:00:00.067',
#     'endTime': '0:00:19.853',
#     'startSeconds': 0.1,
#     'endSeconds': 19.9}]}]

# %%
keyframes = []
for shot in info["videos"][0]["insights"]["shots"]:
    for keyframe in shot["keyFrames"]:
        keyframes.append(keyframe["instances"][0]['thumbnailId'])

# %%
for keyframe in keyframes:
    img_str = vi.get_thumbnail_from_video_indexer(video_id,  keyframe)
    #imshow(img_str)
# Out:
# Getting thumbnail from video: fbb0f35f04, thumbnail: d3c8883a-88a3-43a7-9e9f-fbd774311933
# Getting thumbnail from video: fbb0f35f04, thumbnail: a51617ae-35ac-49e7-909c-b1953f537e6a

# %%
imshow(img_str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-49d2af4101f7> in <module>
# ----> 1 imshow(img_str)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2643         filterrad=4.0, imlim=cbook.deprecation._deprecated_parameter,
#    2644         resample=None, url=None, *, data=None, **kwargs):
# -> 2645     __ret = gca().imshow(
#    2646         X, cmap=cmap, norm=norm, aspect=aspect,
#    2647         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5624                               resample=resample, **kwargs)
#    5625
# -> 5626         im.set_data(X)
#    5627         im.set_alpha(alpha)
#    5628         if im.get_clip_path() is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     691         if (self._A.dtype != np.uint8 and
#     692                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 693             raise TypeError("Image data of dtype {} cannot be converted to "
#     694                             "float".format(self._A.dtype))
#     695
#
# TypeError: Image data of dtype |S75295 cannot be converted to float

# %%
import datetime
import pandas as pd
from PIL import Image
import requests
import io

from matplotlib.pyplot import imshow
# %matplotlib inline

# %%
vi.get_thumbnail_from_video_indexer('fbb0f35f04','508dda6c-ca43-4198-af20-d1016df0cc76')
# Out:
# Getting thumbnail from video: fbb0f35f04, thumbnail: 508dda6c-ca43-4198-af20-d1016df0cc76
# b'\xff\xd8\xff\xfe\x00\x10Lavc58.91.100\x00\xff\xdb\x00C\x00\x08\x04\x04\x04\x04\x04\x05\x05\x05\x05\x05\x05\x06\x06\x06\x06\x06\x06\x06\x06\x06\x06\x06\x06\x06\x07\x07\x07\x08\x08\x08\x07\x07\x07\x06\x06\x07\x07\x08\x08\x08\x08\t\t\t\x08\x08\x08\x08\t\t\n\n\n!1\x12\x04"QA\x05\x06q\x13a2\xa1\x91\x81\xc1\xb1B\xf0#\x07\xd1R\xe1\x14\x153\xf1br\x16\x82$C\x924Sc\xd2T\xb2\x11\x00\x02\x02\x01\x04\x02\x01\x03\x03\x03\x04\x02\x03\x01\x00\x00\x00\x01\x02\x11!1\x12A\x03\x04Qa\x13\x05"\x81q2B\xa1\x14\xc13\x91\xf0\xd1#\xf1\xb1R\x06\xff\xc0\x00\x11\x08\x01\xc6\x01h\x03\x01"\x00\x02\x11\x00\x03\x11\x00\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\x03\xa0\x91\xd3,S\x1cW\xde\xdf@\xaa\x15!K\xf4\xf4\xa4\xf9e\xf9^B+S,T\xa8\xbd\n\xa5#\xa2\xa1\xc1`\xb2\xbf,w\'\x8d?\xef\xc1\xe8\x8dF\xf0W`\x01\xfe\xd3B\xe2\xe54AM-K7\x87\xcf\xf3\xb7\x18\xf54\x9bD\xbd\xb3Xa67\x14 i\xe8\xe1l\xb1|\xf0\xca\xee\xd3\xe0\\\xdbJ$\xe2\x
\xa5?v\x1e\x7f\\\xf6\xed\xa2~\x0e\x0b\xaf\xe4a2\xf5\xdb\xf4\xf2\xe1\xeb\xba\xb0\xbf\xc79\xba\xc1u\x99\xee[0v\x85\xf2\xb4\xf5\xb6|\n1\x87\x96\x1b\xd6\xccc\x96hT\x9b8lBM\xf2\xb6{V\x82P\xce\xecT6{\xca\x07]o\x87.\xa4\x04\xde6\xa96\xc6\xdd;\x17s\x972)\x17~#\xf0\x16\\\x18\xf2\xda\x954\x19\xe2\xe9\xb5\xbb\x00PY\n@\xa3\n@\x80%\xab\x11 \xb5j\x15\xa8[x\x1f}}\xa2\xd6\xf9\x8f\xa6\xa4\x92\xc9U\xdf_h\xb5\xbe\x8f\xf4\xd4\x92Uz\xb1\xfe\xb3\xe2<\xb9s~i\xa6\x9ak@\xd3M5#]\xde\xed~\xf1\xa5\xf3\xbfb\xf5\xc2]\xee\xec_\x9c\xe9r\xff\x00\x1b\xec*"\xf0g1\xeb\x11x\xb6\x1d+\x08\xc0\xcd\xda\xb4\x81\x80\x102%g\x0c\x93\'a\x8c\xa5ruf\x16\xf0\xfd\xe9\x91\x06-\xbd\x11q\x9b\x0e\xcd\xbd\xabc;\xfd\xc4\xa8\xb0el\x0e\'\x14\x18\x0ben\x94px~m\xf2s\xdc\xb0[\x0e\x89\xc7\xb5I\xa0@\x8c\xbc\xbe+\x03f\xc4\xc7n\xc4@\x19\xc7`Y\x00\x9f\xec\xe1\xd4\xa2q\xb3\x0b \x80\x0e\xd5\xb1\xd2\x88\xdf\xc1\xd6\x84\tn\x03\xb0\xd9\x11\x0b\x08\xb8\x822NL\xc7L)\xa6[\xe3\x7fZ{\x8fb\'\t\x07<\xec\xb1\xd7\x91;2\xc5H\x96\xef5r\xda\r\xa40<.wS\x80\t\x19P%\x8fy)K\x000-~\xa7JDU{\x9d`xG\xc4\xaf\xb3\xf8\xfd\xb8zq\xff\x00\xecx\xf3\xdd\xce\xa2\xaf\x02\xadN\xd1\x1dm\n\x91\x02M\xe7\xb1L\xff\x00\x16\xcb\x9b\x9d\xf7Px\xe2p\xf5#<\xf6\xa4N\xd7\xd6kxZj5\xbb\x01\xe1\x1d\xa8@sp\x81\xd6\xa1\x97\x9c\xd6\x1e=\xab\x97v\x13\xfd\xb7\xac\xbfK\x8e\xa9^\xa4q\xbb\x8e0\xe2q1\xd2\x98/\x1f\x94\x1e\xc2\xa8K\xff\x00\x12~1\xe32\xb5\x8exO\x12h^\xeb\xe ...

# %%
vi.check_access_token()

# %%
vi.extract_summary_from_video_indexer_info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-72d7987c9b63> in <module>
# ----> 1 vi.extract_summary_from_video_indexer_info()
#
# TypeError: extract_summary_from_video_indexer_info() missing 1 required positional argument: 'info'

# %%
vi.get_caption_from_video_indexer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-df2eeead7059> in <module>
# ----> 1 vi.get_caption_from_video_indexer()
#
# TypeError: get_caption_from_video_indexer() missing 1 required positional argument: 'video_id'

# %%
video_id = vi.upload_to_video_indexer(
   input_filename='some-video.mp4',
   video_name='some-video-name',  # identifier for video in Video Indexer platform, must be unique during indexing time
   video_language='English'
)
